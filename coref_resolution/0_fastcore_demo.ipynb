# %% [markdown]
# ## Fast-Coref model demo

# %% [markdown]
# ### Installation Requirements

# %% [markdown]
# ##### In order to use Fast-Coref model, run: **pip install fastcoref**
# #### For more information read [this repo](http://https://github.com/shon-otmazgin/fastcoref)
# #### Note: In order to use the model, you may need a GPU

# %%
pip install fastcoref

# %% [markdown]
# ## Quick start with an Example

# %%
from fastcoref import FCoref

model = FCoref(device='cuda:0')

# read the text file (fulltext of ATel no. 16146)
with open('text_example') as f:
    f = f.read()
    
preds = model.predict(texts=[f])
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# ...

# %%
# get the clusters of mentions
preds[0].get_clusters()
# Out:
# [['the blazars sample',
#   'its',
#   "blazar's",
#   "it's",
#   'The object',
#   'the blazar',
#   'the blazar',
#   'its'],
#  ['Our team', 'Our', 'we', 'Our', 'us', 'our', 'Our', 'We'],
#  ['1-meter Zeiss-1000 and 0.5-meter RC-500 reflectors, equipped with BVRI CCD photometers',
#   'these telescopes',
#   'the both telescopes'],
#  ['June', 'June'],
#  ['S4 0133+47', 'S4 0133+47'],
#  ['0.5-meter RC-500', 'RC-500', 'RC-500 telescope']]

# %%
# get start and end spans of detected mentions
preds[0].get_clusters(as_strings=False)
