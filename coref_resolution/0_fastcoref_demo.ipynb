# %% [markdown]
# ## Fast-Coref model demo

# %% [markdown]
# ### Installation Requirements

# %% [markdown]
# ###### In order to use Fast-Coref model, run: **pip install fastcoref**
# ###### For more information read [this repo](http://https://github.com/shon-otmazgin/fastcoref)
# ###### For a demo : [https://huggingface.co/spaces/pythiccoder/FastCoref](https://huggingface.co/spaces/pythiccoder/FastCoref)

# %%
pip install fastcoref
# Out:
# Requirement already satisfied: fastcoref in /home/alkan/miniconda3/lib/python3.9/site-packages (2.1.6)
# Requirement already satisfied: spacy>=3.0.6 in /home/alkan/miniconda3/lib/python3.9/site-packages (from fastcoref) (3.4.4)
# Requirement already satisfied: transformers>=4.11.3 in /home/alkan/miniconda3/lib/python3.9/site-packages (from fastcoref) (4.25.1)
# Requirement already satisfied: torch>=1.10.0 in /home/alkan/miniconda3/lib/python3.9/site-packages (from fastcoref) (1.13.0)
# Requirement already satisfied: datasets>=2.5.2 in /home/alkan/miniconda3/lib/python3.9/site-packages (from fastcoref) (2.14.0)
# Requirement already satisfied: tqdm>=4.64.0 in /home/alkan/miniconda3/lib/python3.9/site-packages (from fastcoref) (4.65.0)
# Requirement already satisfied: scipy>=1.7.3 in /home/alkan/miniconda3/lib/python3.9/site-packages (from fastcoref) (1.9.3)
# Requirement already satisfied: numpy>=1.21.6 in /home/alkan/miniconda3/lib/python3.9/site-packages (from fastcoref) (1.23.5)
# Requirement already satisfied: pyyaml>=5.1 in /home/alkan/miniconda3/lib/python3.9/site-packages (from datasets>=2.5.2->fastcoref) (6.0)
# Requirement already satisfied: aiohttp in /home/alkan/miniconda3/lib/python3.9/site-packages (from datasets>=2.5.2->fastcoref) (3.8.5)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.14.0 in /home/alkan/miniconda3/lib/python3.9/site-packages (from datasets>=2.5.2->fastcoref) (0.16.4)
# Requirement already satisfied: packaging in /home/alkan/miniconda3/lib/python3.9/site-packages (from datasets>=2.5.2->fastcoref) (21.3)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /home/alkan/miniconda3/lib/python3.9/site-packages (from datasets>=2.5.2->fastcoref) (0.3.7)
# Requirement already satisfied: multiprocess in /home/alkan/miniconda3/lib/python3.9/site-packages (from datasets>=2.5.2->fastcoref) (0.70.15)
# Requirement already satisfied: pyarrow>=8.0.0 in /home/alkan/miniconda3/lib/python3.9/site-packages (from datasets>=2.5.2->fastcoref) (12.0.1)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /home/alkan/miniconda3/lib/python3.9/site-packages (from datasets>=2.5.2->fastcoref) (2023.6.0)
# Requirement already satisfied: requests>=2.19.0 in /home/alkan/miniconda3/lib/python3.9/site-packages (from datasets>=2.5.2->fastcoref) (2.27.1)
# Requirement already satisfied: xxhash in /home/alkan/miniconda3/lib/python3.9/site-packages (from datasets>=2.5.2->fastcoref) (3.2.0)
# Requirement already satisfied: pandas in /home/alkan/miniconda3/lib/python3.9/site-packages (from datasets>=2.5.2->fastcoref) (1.5.2)
# Requirement already satisfied: setuptools in /home/alkan/miniconda3/lib/python3.9/site-packages (from spacy>=3.0.6->fastcoref) (66.0.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/alkan/miniconda3/lib/python3.9/site-packages (from spacy>=3.0.6->fastcoref) (1.0.4)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /home/alkan/miniconda3/lib/python3.9/site-packages (from spacy>=3.0.6->fastcoref) (8.1.10)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /home/alkan/miniconda3/lib/python3.9/site-packages (from spacy>=3.0.6->fastcoref) (0.10.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/alkan/miniconda3/lib/python3.9/site-packages (from spacy>=3.0.6->fastcoref) (3.0.8)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /home/alkan/miniconda3/lib/python3.9/site-packages (from spacy>=3.0.6->fastcoref) (1.10.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/alkan/miniconda3/lib/python3.9/site-packages (from spacy>=3.0.6->fastcoref) (1.0.9)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/alkan/miniconda3/lib/python3.9/site-packages (from spacy>=3.0.6->fastcoref) (3.3.0)
# Requirement already satisfied: pathy>=0.3.5 in /home/alkan/miniconda3/lib/python3.9/site-packages (from spacy>=3.0.6->fastcoref) (0.10.1)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /home/alkan/miniconda3/lib/python3.9/site-packages (from spacy>=3.0.6->fastcoref) (0.7.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/alkan/miniconda3/lib/python3.9/site-packages (from spacy>=3.0.6->fastcoref) (6.2.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/alkan/miniconda3/lib/python3.9/site-packages (from spacy>=3.0.6->fastcoref) (2.0.9)
# Requirement already satisfied: jinja2 in /home/alkan/miniconda3/lib/python3.9/site-packages (from spacy>=3.0.6->fastcoref) (3.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/alkan/miniconda3/lib/python3.9/site-packages (from spacy>=3.0.6->fastcoref) (2.4.7)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /home/alkan/miniconda3/lib/python3.9/site-packages (from spacy>=3.0.6->fastcoref) (3.0.11)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/alkan/miniconda3/lib/python3.9/site-packages (from spacy>=3.0.6->fastcoref) (2.0.7)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/alkan/miniconda3/lib/python3.9/site-packages (from torch>=1.10.0->fastcoref) (11.7.99)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/alkan/miniconda3/lib/python3.9/site-packages (from torch>=1.10.0->fastcoref) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/alkan/miniconda3/lib/python3.9/site-packages (from torch>=1.10.0->fastcoref) (11.7.99)
# Requirement already satisfied: typing-extensions in /home/alkan/miniconda3/lib/python3.9/site-packages (from torch>=1.10.0->fastcoref) (4.4.0)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/alkan/miniconda3/lib/python3.9/site-packages (from torch>=1.10.0->fastcoref) (8.5.0.96)
# Requirement already satisfied: wheel in /home/alkan/miniconda3/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.10.0->fastcoref) (0.38.4)
# Requirement already satisfied: regex!=2019.12.17 in /home/alkan/miniconda3/lib/python3.9/site-packages (from transformers>=4.11.3->fastcoref) (2022.10.31)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /home/alkan/miniconda3/lib/python3.9/site-packages (from transformers>=4.11.3->fastcoref) (0.12.1)
# Requirement already satisfied: filelock in /home/alkan/miniconda3/lib/python3.9/site-packages (from transformers>=4.11.3->fastcoref) (3.8.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/alkan/miniconda3/lib/python3.9/site-packages (from aiohttp->datasets>=2.5.2->fastcoref) (4.0.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/alkan/miniconda3/lib/python3.9/site-packages (from aiohttp->datasets>=2.5.2->fastcoref) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/alkan/miniconda3/lib/python3.9/site-packages (from aiohttp->datasets>=2.5.2->fastcoref) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/alkan/miniconda3/lib/python3.9/site-packages (from aiohttp->datasets>=2.5.2->fastcoref) (1.3.1)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /home/alkan/miniconda3/lib/python3.9/site-packages (from aiohttp->datasets>=2.5.2->fastcoref) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/alkan/miniconda3/lib/python3.9/site-packages (from aiohttp->datasets>=2.5.2->fastcoref) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/alkan/miniconda3/lib/python3.9/site-packages (from aiohttp->datasets>=2.5.2->fastcoref) (1.9.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/alkan/miniconda3/lib/python3.9/site-packages (from packaging->datasets>=2.5.2->fastcoref) (3.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in /home/alkan/miniconda3/lib/python3.9/site-packages (from requests>=2.19.0->datasets>=2.5.2->fastcoref) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/alkan/miniconda3/lib/python3.9/site-packages (from requests>=2.19.0->datasets>=2.5.2->fastcoref) (1.26.8)
# Requirement already satisfied: idna<4,>=2.5 in /home/alkan/miniconda3/lib/python3.9/site-packages (from requests>=2.19.0->datasets>=2.5.2->fastcoref) (3.3)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/alkan/miniconda3/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.0->spacy>=3.0.6->fastcoref) (0.0.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/alkan/miniconda3/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.0->spacy>=3.0.6->fastcoref) (0.7.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/alkan/miniconda3/lib/python3.9/site-packages (from typer<0.8.0,>=0.3.0->spacy>=3.0.6->fastcoref) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/alkan/miniconda3/lib/python3.9/site-packages (from jinja2->spacy>=3.0.6->fastcoref) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/alkan/miniconda3/lib/python3.9/site-packages (from pandas->datasets>=2.5.2->fastcoref) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/alkan/miniconda3/lib/python3.9/site-packages (from pandas->datasets>=2.5.2->fastcoref) (2022.6)
# Requirement already satisfied: six>=1.5 in /home/alkan/miniconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas->datasets>=2.5.2->fastcoref) (1.16.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Quick start with an Example

# %%
from fastcoref import FCoref

model = FCoref(device='cpu') # or FCoref(device='cuda:0') if you want to use a GPU

# read the text file (fulltext of ATel no. 16146)
with open('text_example') as f:
    f = f.read()

sentence = 'We report the discovery of a possible nova located at'
preds = model.predict(texts=[sentence])
# Out:
# /home/alkan/miniconda3/lib/python3.9/site-packages/spacy/util.py:877: UserWarning: [W095] Model 'en_core_web_sm' (3.6.0) was trained with spaCy v3.6 and may not be 100% compatible with the current version (3.4.4). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# 07/26/2023 11:39:12 - INFO - 	 missing_keys: []
# 07/26/2023 11:39:12 - INFO - 	 unexpected_keys: []
# 07/26/2023 11:39:12 - INFO - 	 mismatched_keys: []
# 07/26/2023 11:39:12 - INFO - 	 error_msgs: []
# 07/26/2023 11:39:12 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 07/26/2023 11:39:12 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 191.71 examples/s]
# 07/26/2023 11:39:12 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 21.33it/s]

# %%
# get the clusters of mentions
preds[0].get_clusters()
# Out:
# []

# %%
# get start and end spans of detected mentions
preds[0].get_clusters(as_strings=False)
# Out:
# []
